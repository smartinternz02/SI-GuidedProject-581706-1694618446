# %%
import pandas as pd
import numpy as np

# %%
data = np.random.rand(4, 4)
df = pd.DataFrame(data)
df
# Out:
#           0         1         2         3
# 0  0.775752  0.849578  0.293069  0.665742
# 1  0.728352  0.617878  0.975889  0.304435
# 2  0.988843  0.047055  0.136435  0.113823
# 3  0.387238  0.001408  0.755725  0.779345

# %%
df.columns=['Random value 1','Random value 2','Random value 3','Random value 4']
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.775752        0.849578        0.293069        0.665742
# 1        0.728352        0.617878        0.975889        0.304435
# 2        0.988843        0.047055        0.136435        0.113823
# 3        0.387238        0.001408        0.755725        0.779345

# %%
df.describe()
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.720046        0.378980        0.540280        0.465836
# std          0.249122        0.420821        0.391738        0.309953
# min          0.387238        0.001408        0.136435        0.113823
# 25%          0.643074        0.035643        0.253911        0.256782
# 50%          0.752052        0.332466        0.524397        0.485089
# 75%          0.829025        0.675803        0.810766        0.694143
# max          0.988843        0.849578        0.975889        0.779345

# %%
df.isnull().sum() #no null values
# Out:
# Random value 1    0
# Random value 2    0
# Random value 3    0
# Random value 4    0
# dtype: int64

# %%
df.dtypes
# Out:
# Random value 1    float64
# Random value 2    float64
# Random value 3    float64
# Random value 4    float64
# dtype: object

# %%
df.loc[:, ['Random value 2', 'Random value 3']] #location method
# Out:
#    Random value 2  Random value 3
# 0        0.849578        0.293069
# 1        0.617878        0.975889
# 2        0.047055        0.136435
# 3        0.001408        0.755725

# %%
df.iloc[:, [1, 2]]#index location method
# Out:
#    Random value 2  Random value 3
# 0        0.849578        0.293069
# 1        0.617878        0.975889
# 2        0.047055        0.136435
# 3        0.001408        0.755725
